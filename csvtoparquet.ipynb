# %%
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq

# %%
def convert_csv_to_parquet(input_file_path, output_file_path, drop_option):
    # Read CSV file into a Pandas DataFrame
    df = pd.read_csv(input_file_path)

    # Remove rows or columns with NaN fields based on the drop_option argument
    if drop_option == 'row':
        df = df.dropna()
    elif drop_option == 'column':
        df = df.dropna(axis=1)

    # Convert Pandas DataFrame to PyArrow Table
    table = pa.Table.from_pandas(df)

    # Write PyArrow Table to Parquet file
    pq.write_table(table, output_file_path)

    # Open the Parquet file
    table = pq.read_table(output_file_path)

    # Convert the table to a Pandas DataFrame
    df = table.to_pandas()

    # Print the DataFrame
    print(df.head(100))

# %%
input_file_path = 'behavior_factor.csv'
output_file_path = 'bf.parquet'
drop_option = 'column'  # options: 'row' or 'column'

convert_csv_to_parquet(input_file_path, output_file_path, drop_option)
# Out:
#     Unnamed: 0  HeightInMeters  WeightInKilograms    BMI      AgeCategory  \
# 0            0            1.60              71.67  27.99     Age 65 to 69
# 1            1            1.78              95.25  30.13     Age 70 to 74
# 2            2            1.85             108.86  31.66     Age 75 to 79
# 3            3            1.70              90.72  31.32  Age 80 or older
# 4            4            1.55              79.38  33.07  Age 80 or older
# ..         ...             ...                ...    ...              ...
# 95          95            1.80              77.11  23.71     Age 75 to 79
# 96          96            1.68              90.72  32.28     Age 50 to 54
# 97          97            1.70              72.57  25.06  Age 80 or older
# 98          98            1.73             120.20  40.29     Age 45 to 49
# 99          99            1.65              93.89  34.45     Age 60 to 64
#
#      SmokerStatus ECigaretteUsage AlcoholDrinkers PhysicalActivities  \
# 0   Former smoker           Never              No                Yes
# 1   Former smoker           Never              No                Yes
# 2   Former smoker           Never             Yes                 No
# 3    Never smoked           Never              No                Yes
# 4    Never smoked           Never              No                Yes
# ..            ...             ...             ...                ...
# 95  Former smoker           Never             Yes                Yes
# 96   Never smoked      Not at all              No                 No
# 97  Former smoker           Never              No                Yes
# 98  Former smoker           Never              No                Yes
# 99   Never smoked      Not at all              No                 No
#
#     SleepHours HadHeartAttack
# 0          9.0             No
# 1          6.0             No
# 2          8.0             No
# 3          9.0             No
# 4          5.0             No
# ..         ...            ...
# 95         8.0             No
# 96         5.0             No
# 97         7.0             No
# 98         6.0             No
# 99         8.0             No
#
# [100 rows x 11 columns]

# %%
bf = pd.read_parquet('bf.parquet', engine='pyarrow')

# %%
bf
# Out:
#         Unnamed: 0  HeightInMeters  WeightInKilograms    BMI      AgeCategory  \
# 0                0            1.60              71.67  27.99     Age 65 to 69
# 1                1            1.78              95.25  30.13     Age 70 to 74
# 2                2            1.85             108.86  31.66     Age 75 to 79
# 3                3            1.70              90.72  31.32  Age 80 or older
# 4                4            1.55              79.38  33.07  Age 80 or older
# ...            ...             ...                ...    ...              ...
# 234314      234314            1.78             102.06  32.28     Age 60 to 64
# 234315      234315            1.93              90.72  24.34     Age 25 to 29
# 234316      234316            1.68              83.91  29.86     Age 65 to 69
# 234317      234317            1.70              83.01  28.66     Age 50 to 54
# 234318      234318            1.83             108.86  32.55     Age 70 to 74
#
#          SmokerStatus ECigaretteUsage AlcoholDrinkers PhysicalActivities  \
# 0       Former smoker           Never              No                Yes
# 1       Former smoker           Never              No                Yes
# 2       Former smoker           Never             Yes                 No
# 3        Never smoked           Never              No                Yes
# 4        Never smoked           Never              No                Yes
# ...               ...             ...             ...                ...
# 234314   Never smoked           Never             Yes                Yes
# 234315   Never smoked           Never              No                Yes
# 234316   Never smoked           Never             Yes                Yes
# 234317   Never smoked           Never              No                Yes
# 234318   Never smoked           Never              No                 No
#
#         SleepHours HadHeartAttack
# 0              9.0             No
# 1              6.0             No
# 2              8.0             No
# 3              9.0             No
# 4              5.0             No
# ...            ...            ...
# 234314         6.0             No
# 234315         7.0             No
# 234316         7.0             No
# 234317         7.0             No
# 234318         5.0            Yes
#
# [234319 rows x 11 columns]

# %%
bf = bf.drop(bf.columns[0], axis=1)

# %%
bf
# Out:
#         HeightInMeters  WeightInKilograms    BMI      AgeCategory  \
# 0                 1.60              71.67  27.99     Age 65 to 69
# 1                 1.78              95.25  30.13     Age 70 to 74
# 2                 1.85             108.86  31.66     Age 75 to 79
# 3                 1.70              90.72  31.32  Age 80 or older
# 4                 1.55              79.38  33.07  Age 80 or older
# ...                ...                ...    ...              ...
# 234314            1.78             102.06  32.28     Age 60 to 64
# 234315            1.93              90.72  24.34     Age 25 to 29
# 234316            1.68              83.91  29.86     Age 65 to 69
# 234317            1.70              83.01  28.66     Age 50 to 54
# 234318            1.83             108.86  32.55     Age 70 to 74
#
#          SmokerStatus ECigaretteUsage AlcoholDrinkers PhysicalActivities  \
# 0       Former smoker           Never              No                Yes
# 1       Former smoker           Never              No                Yes
# 2       Former smoker           Never             Yes                 No
# 3        Never smoked           Never              No                Yes
# 4        Never smoked           Never              No                Yes
# ...               ...             ...             ...                ...
# 234314   Never smoked           Never             Yes                Yes
# 234315   Never smoked           Never              No                Yes
# 234316   Never smoked           Never             Yes                Yes
# 234317   Never smoked           Never              No                Yes
# 234318   Never smoked           Never              No                 No
#
#         SleepHours HadHeartAttack
# 0              9.0             No
# 1              6.0             No
# 2              8.0             No
# 3              9.0             No
# 4              5.0             No
# ...            ...            ...
# 234314         6.0             No
# 234315         7.0             No
# 234316         7.0             No
# 234317         7.0             No
# 234318         5.0            Yes
#
# [234319 rows x 10 columns]
